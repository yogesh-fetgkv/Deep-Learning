# %% [markdown]
# <a href="https://colab.research.google.com/github/yogesh-fetgkv/Deep-Learning/blob/main/contour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
x=np.linspace(-2,2,10)
y=np.linspace(-2,2,10)
X,Y=np.meshgrid(x,y)
z=X**2+Y**2
fig=plt.figure(figsize=(12,8))
ax=fig.gca(projection='3d')
ax.plot_surface(X,Y,z,cmap=cm.coolwarm)
plt.show()

# %%
plt.contour(X,Y,z,cmap=cm.coolwarm)
plt.show()
